# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 890us/sample - loss: 236.5476 - y1_output_loss: 109.0010 - y2_output_loss: 125.3011 - y1_output_root_mean_squared_error: 10.4903 - y2_output_root_mean_squared_error: 11.2473 - val_loss: 27.6595 - val_y1_output_loss: 12.2279 - val_y2_output_loss: 15.8269 - val_y1_output_root_mean_squared_error: 3.4762 - val_y2_output_root_mean_squared_error: 3.9466
# Epoch 2/500
# 614/614 [==============================] - 0s 134us/sample - loss: 32.0803 - y1_output_loss: 11.9719 - y2_output_loss: 19.8180 - y1_output_root_mean_squared_error: 3.4761 - y2_output_root_mean_squared_error: 4.4718 - val_loss: 20.7504 - val_y1_output_loss: 8.3615 - val_y2_output_loss: 12.1173 - val_y1_output_root_mean_squared_error: 2.9244 - val_y2_output_root_mean_squared_error: 3.4926
# Epoch 3/500
# 614/614 [==============================] - 0s 135us/sample - loss: 26.2904 - y1_output_loss: 10.1296 - y2_output_loss: 15.9223 - y1_output_root_mean_squared_error: 3.1967 - y2_output_root_mean_squared_error: 4.0089 - val_loss: 19.4735 - val_y1_output_loss: 7.9093 - val_y2_output_loss: 11.1293 - val_y1_output_root_mean_squared_error: 2.8506 - val_y2_output_root_mean_squared_error: 3.3686
# Epoch 4/500
# 614/614 [==============================] - 0s 131us/sample - loss: 26.1322 - y1_output_loss: 9.8193 - y2_output_loss: 16.5235 - y1_output_root_mean_squared_error: 3.1310 - y2_output_root_mean_squared_error: 4.0409 - val_loss: 36.5474 - val_y1_output_loss: 11.6253 - val_y2_output_loss: 24.8959 - val_y1_output_root_mean_squared_error: 3.4275 - val_y2_output_root_mean_squared_error: 4.9799
# Epoch 5/500
# 614/614 [==============================] - 0s 127us/sample - loss: 24.0625 - y1_output_loss: 9.3839 - y2_output_loss: 14.5818 - y1_output_root_mean_squared_error: 3.0689 - y2_output_root_mean_squared_error: 3.8268 - val_loss: 24.9577 - val_y1_output_loss: 9.3413 - val_y2_output_loss: 14.9719 - val_y1_output_root_mean_squared_error: 3.1107 - val_y2_output_root_mean_squared_error: 3.9092
# Epoch 6/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.5318 - y1_output_loss: 9.3699 - y2_output_loss: 15.2284 - y1_output_root_mean_squared_error: 3.0618 - y2_output_root_mean_squared_error: 3.8932 - val_loss: 66.0904 - val_y1_output_loss: 14.5019 - val_y2_output_loss: 51.9048 - val_y1_output_root_mean_squared_error: 3.8142 - val_y2_output_root_mean_squared_error: 7.1793
# Epoch 7/500
# 614/614 [==============================] - 0s 135us/sample - loss: 23.9029 - y1_output_loss: 9.2110 - y2_output_loss: 15.0990 - y1_output_root_mean_squared_error: 3.0100 - y2_output_root_mean_squared_error: 3.8527 - val_loss: 44.8593 - val_y1_output_loss: 11.0348 - val_y2_output_loss: 33.5341 - val_y1_output_root_mean_squared_error: 3.3543 - val_y2_output_root_mean_squared_error: 5.7973
# Epoch 8/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.8283 - y1_output_loss: 8.1803 - y2_output_loss: 11.6759 - y1_output_root_mean_squared_error: 2.8523 - y2_output_root_mean_squared_error: 3.4194 - val_loss: 19.2418 - val_y1_output_loss: 8.0916 - val_y2_output_loss: 10.6020 - val_y1_output_root_mean_squared_error: 2.8975 - val_y2_output_root_mean_squared_error: 3.2934
# Epoch 9/500
# 614/614 [==============================] - 0s 127us/sample - loss: 21.7258 - y1_output_loss: 8.3832 - y2_output_loss: 13.1804 - y1_output_root_mean_squared_error: 2.9091 - y2_output_root_mean_squared_error: 3.6418 - val_loss: 20.3547 - val_y1_output_loss: 8.0489 - val_y2_output_loss: 11.9306 - val_y1_output_root_mean_squared_error: 2.8788 - val_y2_output_root_mean_squared_error: 3.4738
# Epoch 10/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.3569 - y1_output_loss: 8.1046 - y2_output_loss: 12.2947 - y1_output_root_mean_squared_error: 2.8264 - y2_output_root_mean_squared_error: 3.5168 - val_loss: 20.5397 - val_y1_output_loss: 8.6465 - val_y2_output_loss: 11.5829 - val_y1_output_root_mean_squared_error: 2.9694 - val_y2_output_root_mean_squared_error: 3.4238
# Epoch 11/500
# 614/614 [==============================] - 0s 130us/sample - loss: 23.1812 - y1_output_loss: 8.6129 - y2_output_loss: 14.7281 - y1_output_root_mean_squared_error: 2.9205 - y2_output_root_mean_squared_error: 3.8278 - val_loss: 27.5752 - val_y1_output_loss: 9.8377 - val_y2_output_loss: 16.9833 - val_y1_output_root_mean_squared_error: 3.1919 - val_y2_output_root_mean_squared_error: 4.1697
# Epoch 12/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.4125 - y1_output_loss: 7.4468 - y2_output_loss: 10.8975 - y1_output_root_mean_squared_error: 2.7382 - y2_output_root_mean_squared_error: 3.3037 - val_loss: 17.4896 - val_y1_output_loss: 6.8033 - val_y2_output_loss: 10.2283 - val_y1_output_root_mean_squared_error: 2.6512 - val_y2_output_root_mean_squared_error: 3.2343
# Epoch 13/500
# 614/614 [==============================] - 0s 130us/sample - loss: 20.9883 - y1_output_loss: 7.4723 - y2_output_loss: 13.5333 - y1_output_root_mean_squared_error: 2.7341 - y2_output_root_mean_squared_error: 3.6760 - val_loss: 21.4937 - val_y1_output_loss: 7.6418 - val_y2_output_loss: 13.4876 - val_y1_output_root_mean_squared_error: 2.8049 - val_y2_output_root_mean_squared_error: 3.6914
# Epoch 14/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.6449 - y1_output_loss: 7.5094 - y2_output_loss: 12.1770 - y1_output_root_mean_squared_error: 2.7429 - y2_output_root_mean_squared_error: 3.4815 - val_loss: 32.4568 - val_y1_output_loss: 10.6543 - val_y2_output_loss: 21.1873 - val_y1_output_root_mean_squared_error: 3.3046 - val_y2_output_root_mean_squared_error: 4.6408
# Epoch 15/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.9081 - y1_output_loss: 6.5175 - y2_output_loss: 10.2480 - y1_output_root_mean_squared_error: 2.5642 - y2_output_root_mean_squared_error: 3.2145 - val_loss: 16.9490 - val_y1_output_loss: 6.4432 - val_y2_output_loss: 10.0785 - val_y1_output_root_mean_squared_error: 2.5831 - val_y2_output_root_mean_squared_error: 3.2057
# Epoch 16/500
# 614/614 [==============================] - 0s 140us/sample - loss: 17.2750 - y1_output_loss: 6.6529 - y2_output_loss: 10.6018 - y1_output_root_mean_squared_error: 2.5681 - y2_output_root_mean_squared_error: 3.2680 - val_loss: 16.7055 - val_y1_output_loss: 6.8056 - val_y2_output_loss: 9.4507 - val_y1_output_root_mean_squared_error: 2.6534 - val_y2_output_root_mean_squared_error: 3.1089
# Epoch 17/500
# 614/614 [==============================] - 0s 139us/sample - loss: 19.0429 - y1_output_loss: 6.8913 - y2_output_loss: 11.9888 - y1_output_root_mean_squared_error: 2.6374 - y2_output_root_mean_squared_error: 3.4766 - val_loss: 14.5516 - val_y1_output_loss: 5.7598 - val_y2_output_loss: 8.4470 - val_y1_output_root_mean_squared_error: 2.4358 - val_y2_output_root_mean_squared_error: 2.9357
# Epoch 18/500
# 614/614 [==============================] - 0s 137us/sample - loss: 16.0650 - y1_output_loss: 6.0650 - y2_output_loss: 9.9362 - y1_output_root_mean_squared_error: 2.4599 - y2_output_root_mean_squared_error: 3.1645 - val_loss: 17.4876 - val_y1_output_loss: 6.4264 - val_y2_output_loss: 10.6588 - val_y1_output_root_mean_squared_error: 2.5744 - val_y2_output_root_mean_squared_error: 3.2954
# Epoch 19/500
# 614/614 [==============================] - 0s 137us/sample - loss: 14.8766 - y1_output_loss: 5.6037 - y2_output_loss: 9.2115 - y1_output_root_mean_squared_error: 2.3683 - y2_output_root_mean_squared_error: 3.0443 - val_loss: 14.6017 - val_y1_output_loss: 5.6648 - val_y2_output_loss: 8.5887 - val_y1_output_root_mean_squared_error: 2.4090 - val_y2_output_root_mean_squared_error: 2.9662
# Epoch 20/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.2574 - y1_output_loss: 5.7976 - y2_output_loss: 9.8529 - y1_output_root_mean_squared_error: 2.3833 - y2_output_root_mean_squared_error: 3.0947 - val_loss: 73.2714 - val_y1_output_loss: 11.3062 - val_y2_output_loss: 62.4354 - val_y1_output_root_mean_squared_error: 3.3545 - val_y2_output_root_mean_squared_error: 7.8752
# Epoch 21/500
# 614/614 [==============================] - 0s 137us/sample - loss: 16.7349 - y1_output_loss: 5.7106 - y2_output_loss: 10.9725 - y1_output_root_mean_squared_error: 2.3982 - y2_output_root_mean_squared_error: 3.3142 - val_loss: 12.4456 - val_y1_output_loss: 4.8463 - val_y2_output_loss: 7.2819 - val_y1_output_root_mean_squared_error: 2.2420 - val_y2_output_root_mean_squared_error: 2.7238
# Epoch 22/500
# 614/614 [==============================] - 0s 137us/sample - loss: 14.2165 - y1_output_loss: 5.4982 - y2_output_loss: 8.6438 - y1_output_root_mean_squared_error: 2.3544 - y2_output_root_mean_squared_error: 2.9450 - val_loss: 19.4791 - val_y1_output_loss: 6.3093 - val_y2_output_loss: 12.9442 - val_y1_output_root_mean_squared_error: 2.5338 - val_y2_output_root_mean_squared_error: 3.6137
# Epoch 23/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.8212 - y1_output_loss: 5.5402 - y2_output_loss: 11.1960 - y1_output_root_mean_squared_error: 2.3637 - y2_output_root_mean_squared_error: 3.3517 - val_loss: 29.9821 - val_y1_output_loss: 6.5317 - val_y2_output_loss: 23.5794 - val_y1_output_root_mean_squared_error: 2.5581 - val_y2_output_root_mean_squared_error: 4.8413
# Epoch 24/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.4007 - y1_output_loss: 5.1622 - y2_output_loss: 10.2042 - y1_output_root_mean_squared_error: 2.2796 - y2_output_root_mean_squared_error: 3.1944 - val_loss: 14.4602 - val_y1_output_loss: 5.3760 - val_y2_output_loss: 8.6863 - val_y1_output_root_mean_squared_error: 2.3549 - val_y2_output_root_mean_squared_error: 2.9857
# Epoch 25/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.5078 - y1_output_loss: 4.5047 - y2_output_loss: 6.9565 - y1_output_root_mean_squared_error: 2.1211 - y2_output_root_mean_squared_error: 2.6474 - val_loss: 12.0061 - val_y1_output_loss: 5.6379 - val_y2_output_loss: 6.1390 - val_y1_output_root_mean_squared_error: 2.3965 - val_y2_output_root_mean_squared_error: 2.5026
# Epoch 26/500
# 614/614 [==============================] - 0s 126us/sample - loss: 15.6055 - y1_output_loss: 5.0562 - y2_output_loss: 10.4410 - y1_output_root_mean_squared_error: 2.2535 - y2_output_root_mean_squared_error: 3.2446 - val_loss: 9.6611 - val_y1_output_loss: 3.6489 - val_y2_output_loss: 5.7282 - val_y1_output_root_mean_squared_error: 1.9457 - val_y2_output_root_mean_squared_error: 2.4239
# Epoch 27/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.5169 - y1_output_loss: 4.1145 - y2_output_loss: 6.5743 - y1_output_root_mean_squared_error: 2.0251 - y2_output_root_mean_squared_error: 2.5330 - val_loss: 30.4130 - val_y1_output_loss: 6.0255 - val_y2_output_loss: 24.2048 - val_y1_output_root_mean_squared_error: 2.4703 - val_y2_output_root_mean_squared_error: 4.9306
# Epoch 28/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.8513 - y1_output_loss: 3.8707 - y2_output_loss: 6.9842 - y1_output_root_mean_squared_error: 1.9608 - y2_output_root_mean_squared_error: 2.6470 - val_loss: 13.3182 - val_y1_output_loss: 4.6809 - val_y2_output_loss: 8.5799 - val_y1_output_root_mean_squared_error: 2.1694 - val_y2_output_root_mean_squared_error: 2.9346
# Epoch 29/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.4252 - y1_output_loss: 3.6926 - y2_output_loss: 6.8015 - y1_output_root_mean_squared_error: 1.9262 - y2_output_root_mean_squared_error: 2.5913 - val_loss: 17.2203 - val_y1_output_loss: 4.3339 - val_y2_output_loss: 12.7460 - val_y1_output_root_mean_squared_error: 2.0992 - val_y2_output_root_mean_squared_error: 3.5796
# Epoch 30/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.8428 - y1_output_loss: 3.5879 - y2_output_loss: 6.2480 - y1_output_root_mean_squared_error: 1.8969 - y2_output_root_mean_squared_error: 2.4989 - val_loss: 12.3151 - val_y1_output_loss: 4.0141 - val_y2_output_loss: 8.0890 - val_y1_output_root_mean_squared_error: 2.0235 - val_y2_output_root_mean_squared_error: 2.8671
# Epoch 31/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.2590 - y1_output_loss: 3.5372 - y2_output_loss: 5.7129 - y1_output_root_mean_squared_error: 1.8826 - y2_output_root_mean_squared_error: 2.3906 - val_loss: 11.2355 - val_y1_output_loss: 5.0957 - val_y2_output_loss: 5.9753 - val_y1_output_root_mean_squared_error: 2.2688 - val_y2_output_root_mean_squared_error: 2.4674
# Epoch 32/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.1247 - y1_output_loss: 3.7392 - y2_output_loss: 6.4038 - y1_output_root_mean_squared_error: 1.9272 - y2_output_root_mean_squared_error: 2.5319 - val_loss: 19.2748 - val_y1_output_loss: 6.1327 - val_y2_output_loss: 12.9634 - val_y1_output_root_mean_squared_error: 2.4890 - val_y2_output_root_mean_squared_error: 3.6166
# Epoch 33/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.8722 - y1_output_loss: 3.3009 - y2_output_loss: 6.5165 - y1_output_root_mean_squared_error: 1.8239 - y2_output_root_mean_squared_error: 2.5584 - val_loss: 8.9192 - val_y1_output_loss: 3.0246 - val_y2_output_loss: 5.6375 - val_y1_output_root_mean_squared_error: 1.7626 - val_y2_output_root_mean_squared_error: 2.4109
# Epoch 34/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.1615 - y1_output_loss: 3.2997 - y2_output_loss: 5.8907 - y1_output_root_mean_squared_error: 1.8179 - y2_output_root_mean_squared_error: 2.4201 - val_loss: 14.7528 - val_y1_output_loss: 4.0751 - val_y2_output_loss: 10.6336 - val_y1_output_root_mean_squared_error: 2.0247 - val_y2_output_root_mean_squared_error: 3.2640
# Epoch 35/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.0366 - y1_output_loss: 3.1754 - y2_output_loss: 6.0695 - y1_output_root_mean_squared_error: 1.7664 - y2_output_root_mean_squared_error: 2.4324 - val_loss: 19.9423 - val_y1_output_loss: 5.2794 - val_y2_output_loss: 14.9943 - val_y1_output_root_mean_squared_error: 2.2716 - val_y2_output_root_mean_squared_error: 3.8447
# Epoch 36/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.3892 - y1_output_loss: 3.5863 - y2_output_loss: 6.7779 - y1_output_root_mean_squared_error: 1.8868 - y2_output_root_mean_squared_error: 2.6133 - val_loss: 8.9153 - val_y1_output_loss: 2.8968 - val_y2_output_loss: 5.8031 - val_y1_output_root_mean_squared_error: 1.7312 - val_y2_output_root_mean_squared_error: 2.4327
# Epoch 37/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.6324 - y1_output_loss: 3.0044 - y2_output_loss: 5.5865 - y1_output_root_mean_squared_error: 1.7363 - y2_output_root_mean_squared_error: 2.3701 - val_loss: 8.2886 - val_y1_output_loss: 3.0728 - val_y2_output_loss: 5.0744 - val_y1_output_root_mean_squared_error: 1.7698 - val_y2_output_root_mean_squared_error: 2.2708
# Epoch 38/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.4272 - y1_output_loss: 2.8921 - y2_output_loss: 5.5729 - y1_output_root_mean_squared_error: 1.7021 - y2_output_root_mean_squared_error: 2.3516 - val_loss: 10.6868 - val_y1_output_loss: 2.8501 - val_y2_output_loss: 7.8760 - val_y1_output_root_mean_squared_error: 1.6886 - val_y2_output_root_mean_squared_error: 2.7992
# Epoch 39/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.3861 - y1_output_loss: 2.7118 - y2_output_loss: 4.9812 - y1_output_root_mean_squared_error: 1.6284 - y2_output_root_mean_squared_error: 2.1758 - val_loss: 93.0415 - val_y1_output_loss: 33.7068 - val_y2_output_loss: 61.0676 - val_y1_output_root_mean_squared_error: 5.7560 - val_y2_output_root_mean_squared_error: 7.7402
# Epoch 40/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.9678 - y1_output_loss: 3.6868 - y2_output_loss: 7.2488 - y1_output_root_mean_squared_error: 1.9250 - y2_output_root_mean_squared_error: 2.6948 - val_loss: 9.4315 - val_y1_output_loss: 3.3255 - val_y2_output_loss: 5.8199 - val_y1_output_root_mean_squared_error: 1.8425 - val_y2_output_root_mean_squared_error: 2.4570
# Epoch 41/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.3366 - y1_output_loss: 3.2615 - y2_output_loss: 7.2307 - y1_output_root_mean_squared_error: 1.8014 - y2_output_root_mean_squared_error: 2.6630 - val_loss: 31.1876 - val_y1_output_loss: 5.2566 - val_y2_output_loss: 26.0657 - val_y1_output_root_mean_squared_error: 2.2875 - val_y2_output_root_mean_squared_error: 5.0946
# Epoch 42/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.1584 - y1_output_loss: 2.9761 - y2_output_loss: 6.1955 - y1_output_root_mean_squared_error: 1.7140 - y2_output_root_mean_squared_error: 2.4941 - val_loss: 8.4920 - val_y1_output_loss: 2.8640 - val_y2_output_loss: 5.4537 - val_y1_output_root_mean_squared_error: 1.6904 - val_y2_output_root_mean_squared_error: 2.3737
# Epoch 43/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.3308 - y1_output_loss: 2.6566 - y2_output_loss: 5.6085 - y1_output_root_mean_squared_error: 1.6367 - y2_output_root_mean_squared_error: 2.3774 - val_loss: 20.6233 - val_y1_output_loss: 8.7810 - val_y2_output_loss: 12.2215 - val_y1_output_root_mean_squared_error: 2.9503 - val_y2_output_root_mean_squared_error: 3.4524
# Epoch 44/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.7576 - y1_output_loss: 2.7661 - y2_output_loss: 5.9657 - y1_output_root_mean_squared_error: 1.6705 - y2_output_root_mean_squared_error: 2.4428 - val_loss: 7.1531 - val_y1_output_loss: 2.8111 - val_y2_output_loss: 4.2078 - val_y1_output_root_mean_squared_error: 1.6846 - val_y2_output_root_mean_squared_error: 2.0773
# Epoch 45/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.9762 - y1_output_loss: 2.5108 - y2_output_loss: 5.4642 - y1_output_root_mean_squared_error: 1.5723 - y2_output_root_mean_squared_error: 2.3461 - val_loss: 6.9995 - val_y1_output_loss: 2.5608 - val_y2_output_loss: 4.3576 - val_y1_output_root_mean_squared_error: 1.6069 - val_y2_output_root_mean_squared_error: 2.1018
# Epoch 46/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.3874 - y1_output_loss: 2.1676 - y2_output_loss: 4.1658 - y1_output_root_mean_squared_error: 1.4778 - y2_output_root_mean_squared_error: 2.0502 - val_loss: 12.0417 - val_y1_output_loss: 2.9126 - val_y2_output_loss: 9.2743 - val_y1_output_root_mean_squared_error: 1.6964 - val_y2_output_root_mean_squared_error: 3.0272
# Epoch 47/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.7022 - y1_output_loss: 2.8174 - y2_output_loss: 5.9064 - y1_output_root_mean_squared_error: 1.6816 - y2_output_root_mean_squared_error: 2.4237 - val_loss: 16.5157 - val_y1_output_loss: 3.5149 - val_y2_output_loss: 12.6768 - val_y1_output_root_mean_squared_error: 1.8940 - val_y2_output_root_mean_squared_error: 3.5956
# Epoch 48/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.6222 - y1_output_loss: 3.0241 - y2_output_loss: 6.6528 - y1_output_root_mean_squared_error: 1.7341 - y2_output_root_mean_squared_error: 2.5720 - val_loss: 26.6355 - val_y1_output_loss: 8.3666 - val_y2_output_loss: 19.0398 - val_y1_output_root_mean_squared_error: 2.8302 - val_y2_output_root_mean_squared_error: 4.3157
# Epoch 49/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.8161 - y1_output_loss: 4.8441 - y2_output_loss: 10.8603 - y1_output_root_mean_squared_error: 2.2099 - y2_output_root_mean_squared_error: 3.3064 - val_loss: 8.6910 - val_y1_output_loss: 2.5583 - val_y2_output_loss: 6.1423 - val_y1_output_root_mean_squared_error: 1.5954 - val_y2_output_root_mean_squared_error: 2.4791
# Epoch 50/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.1245 - y1_output_loss: 2.2865 - y2_output_loss: 4.7760 - y1_output_root_mean_squared_error: 1.5191 - y2_output_root_mean_squared_error: 2.1948 - val_loss: 7.1412 - val_y1_output_loss: 2.5466 - val_y2_output_loss: 4.3818 - val_y1_output_root_mean_squared_error: 1.6203 - val_y2_output_root_mean_squared_error: 2.1251
# Epoch 51/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.1283 - y1_output_loss: 3.2551 - y2_output_loss: 6.8489 - y1_output_root_mean_squared_error: 1.8095 - y2_output_root_mean_squared_error: 2.6180 - val_loss: 8.5909 - val_y1_output_loss: 2.6069 - val_y2_output_loss: 5.7348 - val_y1_output_root_mean_squared_error: 1.6371 - val_y2_output_root_mean_squared_error: 2.4312
# Epoch 52/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9152 - y1_output_loss: 2.2083 - y2_output_loss: 4.6597 - y1_output_root_mean_squared_error: 1.4895 - y2_output_root_mean_squared_error: 2.1672 - val_loss: 6.6836 - val_y1_output_loss: 2.3753 - val_y2_output_loss: 4.1955 - val_y1_output_root_mean_squared_error: 1.5512 - val_y2_output_root_mean_squared_error: 2.0682
# Epoch 53/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.9967 - y1_output_loss: 2.4702 - y2_output_loss: 5.6318 - y1_output_root_mean_squared_error: 1.5527 - y2_output_root_mean_squared_error: 2.3634 - val_loss: 13.2532 - val_y1_output_loss: 4.4569 - val_y2_output_loss: 8.4669 - val_y1_output_root_mean_squared_error: 2.1246 - val_y2_output_root_mean_squared_error: 2.9562
# Epoch 54/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.2183 - y1_output_loss: 2.0624 - y2_output_loss: 4.1135 - y1_output_root_mean_squared_error: 1.4413 - y2_output_root_mean_squared_error: 2.0349 - val_loss: 7.3379 - val_y1_output_loss: 2.1715 - val_y2_output_loss: 5.2542 - val_y1_output_root_mean_squared_error: 1.4627 - val_y2_output_root_mean_squared_error: 2.2800
# Epoch 55/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.5815 - y1_output_loss: 1.8969 - y2_output_loss: 4.6462 - y1_output_root_mean_squared_error: 1.3806 - y2_output_root_mean_squared_error: 2.1623 - val_loss: 8.9941 - val_y1_output_loss: 3.0855 - val_y2_output_loss: 5.8476 - val_y1_output_root_mean_squared_error: 1.7625 - val_y2_output_root_mean_squared_error: 2.4265
# Epoch 56/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.7536 - y1_output_loss: 2.0209 - y2_output_loss: 4.6939 - y1_output_root_mean_squared_error: 1.4243 - y2_output_root_mean_squared_error: 2.1737 - val_loss: 11.6188 - val_y1_output_loss: 2.6967 - val_y2_output_loss: 9.0264 - val_y1_output_root_mean_squared_error: 1.6303 - val_y2_output_root_mean_squared_error: 2.9935
# Epoch 57/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.0245 - y1_output_loss: 2.2110 - y2_output_loss: 4.9816 - y1_output_root_mean_squared_error: 1.4770 - y2_output_root_mean_squared_error: 2.2007 - val_loss: 35.3950 - val_y1_output_loss: 8.0007 - val_y2_output_loss: 27.4132 - val_y1_output_root_mean_squared_error: 2.8327 - val_y2_output_root_mean_squared_error: 5.2317
# Epoch 58/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.1093 - y1_output_loss: 1.9974 - y2_output_loss: 4.0968 - y1_output_root_mean_squared_error: 1.4138 - y2_output_root_mean_squared_error: 2.0274 - val_loss: 6.7932 - val_y1_output_loss: 2.1923 - val_y2_output_loss: 4.3994 - val_y1_output_root_mean_squared_error: 1.5053 - val_y2_output_root_mean_squared_error: 2.1278
# Epoch 59/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.4277 - y1_output_loss: 1.7069 - y2_output_loss: 3.6833 - y1_output_root_mean_squared_error: 1.3117 - y2_output_root_mean_squared_error: 1.9254 - val_loss: 7.3773 - val_y1_output_loss: 2.5432 - val_y2_output_loss: 4.6445 - val_y1_output_root_mean_squared_error: 1.6214 - val_y2_output_root_mean_squared_error: 2.1791
# Epoch 60/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.8281 - y1_output_loss: 1.9536 - y2_output_loss: 3.8964 - y1_output_root_mean_squared_error: 1.3895 - y2_output_root_mean_squared_error: 1.9742 - val_loss: 7.6713 - val_y1_output_loss: 2.8724 - val_y2_output_loss: 4.6107 - val_y1_output_root_mean_squared_error: 1.7104 - val_y2_output_root_mean_squared_error: 2.1785
# Epoch 61/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.6037 - y1_output_loss: 2.2824 - y2_output_loss: 5.2847 - y1_output_root_mean_squared_error: 1.5154 - y2_output_root_mean_squared_error: 2.3037 - val_loss: 6.8924 - val_y1_output_loss: 2.1228 - val_y2_output_loss: 4.7798 - val_y1_output_root_mean_squared_error: 1.4564 - val_y2_output_root_mean_squared_error: 2.1844
# Epoch 62/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.7386 - y1_output_loss: 2.1286 - y2_output_loss: 5.7108 - y1_output_root_mean_squared_error: 1.4651 - y2_output_root_mean_squared_error: 2.3648 - val_loss: 21.3197 - val_y1_output_loss: 3.2464 - val_y2_output_loss: 17.9788 - val_y1_output_root_mean_squared_error: 1.8166 - val_y2_output_root_mean_squared_error: 4.2449
# Epoch 63/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.8357 - y1_output_loss: 2.0102 - y2_output_loss: 4.8320 - y1_output_root_mean_squared_error: 1.4210 - y2_output_root_mean_squared_error: 2.1946 - val_loss: 9.2061 - val_y1_output_loss: 3.1924 - val_y2_output_loss: 6.0479 - val_y1_output_root_mean_squared_error: 1.7776 - val_y2_output_root_mean_squared_error: 2.4589
# Epoch 64/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.6592 - y1_output_loss: 1.9618 - y2_output_loss: 4.7134 - y1_output_root_mean_squared_error: 1.3931 - y2_output_root_mean_squared_error: 2.1722 - val_loss: 5.9318 - val_y1_output_loss: 1.8971 - val_y2_output_loss: 3.9340 - val_y1_output_root_mean_squared_error: 1.3843 - val_y2_output_root_mean_squared_error: 2.0039
# Epoch 65/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.3138 - y1_output_loss: 2.0853 - y2_output_loss: 5.2247 - y1_output_root_mean_squared_error: 1.4437 - y2_output_root_mean_squared_error: 2.2868 - val_loss: 13.9942 - val_y1_output_loss: 5.2090 - val_y2_output_loss: 8.5799 - val_y1_output_root_mean_squared_error: 2.2935 - val_y2_output_root_mean_squared_error: 2.9553
# Epoch 66/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.3833 - y1_output_loss: 1.7085 - y2_output_loss: 3.7028 - y1_output_root_mean_squared_error: 1.3066 - y2_output_root_mean_squared_error: 1.9174 - val_loss: 9.9941 - val_y1_output_loss: 2.7865 - val_y2_output_loss: 7.1007 - val_y1_output_root_mean_squared_error: 1.6758 - val_y2_output_root_mean_squared_error: 2.6806
# Epoch 67/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.0978 - y1_output_loss: 1.7377 - y2_output_loss: 4.3218 - y1_output_root_mean_squared_error: 1.3228 - y2_output_root_mean_squared_error: 2.0852 - val_loss: 7.8239 - val_y1_output_loss: 1.9368 - val_y2_output_loss: 5.7451 - val_y1_output_root_mean_squared_error: 1.4041 - val_y2_output_root_mean_squared_error: 2.4191
# Epoch 68/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.4052 - y1_output_loss: 1.8615 - y2_output_loss: 4.4957 - y1_output_root_mean_squared_error: 1.3695 - y2_output_root_mean_squared_error: 2.1283 - val_loss: 12.1815 - val_y1_output_loss: 3.8490 - val_y2_output_loss: 8.5121 - val_y1_output_root_mean_squared_error: 1.9308 - val_y2_output_root_mean_squared_error: 2.9075
# Epoch 69/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.0685 - y1_output_loss: 1.6963 - y2_output_loss: 4.3178 - y1_output_root_mean_squared_error: 1.3087 - y2_output_root_mean_squared_error: 2.0871 - val_loss: 5.8419 - val_y1_output_loss: 1.9459 - val_y2_output_loss: 3.7450 - val_y1_output_root_mean_squared_error: 1.4049 - val_y2_output_root_mean_squared_error: 1.9668
# Epoch 70/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.0911 - y1_output_loss: 2.1101 - y2_output_loss: 4.9264 - y1_output_root_mean_squared_error: 1.4579 - y2_output_root_mean_squared_error: 2.2283 - val_loss: 5.1979 - val_y1_output_loss: 1.5066 - val_y2_output_loss: 3.6183 - val_y1_output_root_mean_squared_error: 1.2363 - val_y2_output_root_mean_squared_error: 1.9156
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.0604 - y1_output_loss: 1.2401 - y2_output_loss: 3.7934 - y1_output_root_mean_squared_error: 1.1184 - y2_output_root_mean_squared_error: 1.9518 - val_loss: 7.8064 - val_y1_output_loss: 1.8730 - val_y2_output_loss: 5.9320 - val_y1_output_root_mean_squared_error: 1.3671 - val_y2_output_root_mean_squared_error: 2.4367
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.5687 - y1_output_loss: 1.3813 - y2_output_loss: 3.1806 - y1_output_root_mean_squared_error: 1.1779 - y2_output_root_mean_squared_error: 1.7836 - val_loss: 5.8397 - val_y1_output_loss: 1.5738 - val_y2_output_loss: 4.1489 - val_y1_output_root_mean_squared_error: 1.2652 - val_y2_output_root_mean_squared_error: 2.0589
# Epoch 73/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.8169 - y1_output_loss: 1.2815 - y2_output_loss: 3.5213 - y1_output_root_mean_squared_error: 1.1345 - y2_output_root_mean_squared_error: 1.8787 - val_loss: 4.6497 - val_y1_output_loss: 1.3857 - val_y2_output_loss: 3.1928 - val_y1_output_root_mean_squared_error: 1.1765 - val_y2_output_root_mean_squared_error: 1.8071
# Epoch 74/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.1441 - y1_output_loss: 1.5137 - y2_output_loss: 4.5980 - y1_output_root_mean_squared_error: 1.2314 - y2_output_root_mean_squared_error: 2.1512 - val_loss: 4.4682 - val_y1_output_loss: 1.4370 - val_y2_output_loss: 2.8853 - val_y1_output_root_mean_squared_error: 1.2175 - val_y2_output_root_mean_squared_error: 1.7280
# Epoch 75/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.6751 - y1_output_loss: 1.4019 - y2_output_loss: 3.2914 - y1_output_root_mean_squared_error: 1.1773 - y2_output_root_mean_squared_error: 1.8136 - val_loss: 6.4644 - val_y1_output_loss: 1.8990 - val_y2_output_loss: 4.4526 - val_y1_output_root_mean_squared_error: 1.3762 - val_y2_output_root_mean_squared_error: 2.1378
# Epoch 76/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9748 - y1_output_loss: 1.1717 - y2_output_loss: 2.8053 - y1_output_root_mean_squared_error: 1.0815 - y2_output_root_mean_squared_error: 1.6748 - val_loss: 4.0033 - val_y1_output_loss: 1.0805 - val_y2_output_loss: 2.9004 - val_y1_output_root_mean_squared_error: 1.0325 - val_y2_output_root_mean_squared_error: 1.7139
# Epoch 77/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.1337 - y1_output_loss: 1.2357 - y2_output_loss: 2.8851 - y1_output_root_mean_squared_error: 1.1127 - y2_output_root_mean_squared_error: 1.7017 - val_loss: 5.0615 - val_y1_output_loss: 0.9921 - val_y2_output_loss: 3.9965 - val_y1_output_root_mean_squared_error: 0.9893 - val_y2_output_root_mean_squared_error: 2.0206
# Epoch 78/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8051 - y1_output_loss: 1.2570 - y2_output_loss: 3.5544 - y1_output_root_mean_squared_error: 1.1232 - y2_output_root_mean_squared_error: 1.8825 - val_loss: 7.9632 - val_y1_output_loss: 1.1055 - val_y2_output_loss: 6.7559 - val_y1_output_root_mean_squared_error: 1.0608 - val_y2_output_root_mean_squared_error: 2.6149
# Epoch 79/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.6729 - y1_output_loss: 0.9356 - y2_output_loss: 2.7172 - y1_output_root_mean_squared_error: 0.9699 - y2_output_root_mean_squared_error: 1.6529 - val_loss: 4.9913 - val_y1_output_loss: 1.1168 - val_y2_output_loss: 3.7752 - val_y1_output_root_mean_squared_error: 1.0612 - val_y2_output_root_mean_squared_error: 1.9660
# Epoch 80/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6358 - y1_output_loss: 0.9453 - y2_output_loss: 2.7188 - y1_output_root_mean_squared_error: 0.9579 - y2_output_root_mean_squared_error: 1.6487 - val_loss: 5.9056 - val_y1_output_loss: 2.0593 - val_y2_output_loss: 3.8111 - val_y1_output_root_mean_squared_error: 1.4377 - val_y2_output_root_mean_squared_error: 1.9592
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.9116 - y1_output_loss: 1.0739 - y2_output_loss: 2.8761 - y1_output_root_mean_squared_error: 1.0258 - y2_output_root_mean_squared_error: 1.6910 - val_loss: 9.2611 - val_y1_output_loss: 2.7229 - val_y2_output_loss: 6.8150 - val_y1_output_root_mean_squared_error: 1.5975 - val_y2_output_root_mean_squared_error: 2.5902
# Epoch 82/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7657 - y1_output_loss: 0.9611 - y2_output_loss: 2.7817 - y1_output_root_mean_squared_error: 0.9825 - y2_output_root_mean_squared_error: 1.6735 - val_loss: 3.7756 - val_y1_output_loss: 1.1962 - val_y2_output_loss: 2.6069 - val_y1_output_root_mean_squared_error: 1.0628 - val_y2_output_root_mean_squared_error: 1.6267
# Epoch 83/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.6602 - y1_output_loss: 2.6951 - y2_output_loss: 6.1328 - y1_output_root_mean_squared_error: 1.6321 - y2_output_root_mean_squared_error: 2.4488 - val_loss: 27.8985 - val_y1_output_loss: 10.6421 - val_y2_output_loss: 18.4537 - val_y1_output_root_mean_squared_error: 3.1684 - val_y2_output_root_mean_squared_error: 4.2261
# Epoch 84/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.7112 - y1_output_loss: 1.2472 - y2_output_loss: 3.4739 - y1_output_root_mean_squared_error: 1.1198 - y2_output_root_mean_squared_error: 1.8594 - val_loss: 3.2943 - val_y1_output_loss: 0.8325 - val_y2_output_loss: 2.4193 - val_y1_output_root_mean_squared_error: 0.9146 - val_y2_output_root_mean_squared_error: 1.5677
# Epoch 85/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.3869 - y1_output_loss: 0.8870 - y2_output_loss: 2.4833 - y1_output_root_mean_squared_error: 0.9428 - y2_output_root_mean_squared_error: 1.5805 - val_loss: 5.1402 - val_y1_output_loss: 1.4726 - val_y2_output_loss: 3.6207 - val_y1_output_root_mean_squared_error: 1.2167 - val_y2_output_root_mean_squared_error: 1.9131
# Epoch 86/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.2903 - y1_output_loss: 0.9752 - y2_output_loss: 3.2870 - y1_output_root_mean_squared_error: 0.9915 - y2_output_root_mean_squared_error: 1.8186 - val_loss: 3.9144 - val_y1_output_loss: 0.8560 - val_y2_output_loss: 2.9636 - val_y1_output_root_mean_squared_error: 0.9334 - val_y2_output_root_mean_squared_error: 1.7444
# Epoch 87/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9708 - y1_output_loss: 0.6765 - y2_output_loss: 2.2957 - y1_output_root_mean_squared_error: 0.8237 - y2_output_root_mean_squared_error: 1.5140 - val_loss: 3.6545 - val_y1_output_loss: 1.1235 - val_y2_output_loss: 2.4318 - val_y1_output_root_mean_squared_error: 1.0728 - val_y2_output_root_mean_squared_error: 1.5822
# Epoch 88/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7829 - y1_output_loss: 0.8976 - y2_output_loss: 2.8604 - y1_output_root_mean_squared_error: 0.9505 - y2_output_root_mean_squared_error: 1.6969 - val_loss: 4.3872 - val_y1_output_loss: 1.2495 - val_y2_output_loss: 3.1500 - val_y1_output_root_mean_squared_error: 1.1028 - val_y2_output_root_mean_squared_error: 1.7807
# Epoch 89/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5734 - y1_output_loss: 0.9251 - y2_output_loss: 2.6328 - y1_output_root_mean_squared_error: 0.9574 - y2_output_root_mean_squared_error: 1.6300 - val_loss: 6.7674 - val_y1_output_loss: 2.0772 - val_y2_output_loss: 4.7267 - val_y1_output_root_mean_squared_error: 1.4422 - val_y2_output_root_mean_squared_error: 2.1650
# Epoch 90/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.2966 - y1_output_loss: 0.8628 - y2_output_loss: 2.4598 - y1_output_root_mean_squared_error: 0.9322 - y2_output_root_mean_squared_error: 1.5581 - val_loss: 10.4475 - val_y1_output_loss: 1.8173 - val_y2_output_loss: 8.6486 - val_y1_output_root_mean_squared_error: 1.3282 - val_y2_output_root_mean_squared_error: 2.9468
# Epoch 91/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.9596 - y1_output_loss: 1.9706 - y2_output_loss: 5.9681 - y1_output_root_mean_squared_error: 1.4034 - y2_output_root_mean_squared_error: 2.4475 - val_loss: 4.7731 - val_y1_output_loss: 1.5470 - val_y2_output_loss: 3.2144 - val_y1_output_root_mean_squared_error: 1.2431 - val_y2_output_root_mean_squared_error: 1.7966
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.4185 - y1_output_loss: 0.8514 - y2_output_loss: 2.5907 - y1_output_root_mean_squared_error: 0.9228 - y2_output_root_mean_squared_error: 1.6022 - val_loss: 4.7048 - val_y1_output_loss: 0.9811 - val_y2_output_loss: 3.7348 - val_y1_output_root_mean_squared_error: 0.9673 - val_y2_output_root_mean_squared_error: 1.9414
# Epoch 93/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.6481 - y1_output_loss: 1.0044 - y2_output_loss: 2.6121 - y1_output_root_mean_squared_error: 1.0070 - y2_output_root_mean_squared_error: 1.6230 - val_loss: 2.6047 - val_y1_output_loss: 0.6208 - val_y2_output_loss: 1.9172 - val_y1_output_root_mean_squared_error: 0.7845 - val_y2_output_root_mean_squared_error: 1.4104
# Epoch 94/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.7357 - y1_output_loss: 1.2552 - y2_output_loss: 3.5187 - y1_output_root_mean_squared_error: 1.1008 - y2_output_root_mean_squared_error: 1.8772 - val_loss: 16.0215 - val_y1_output_loss: 8.1729 - val_y2_output_loss: 8.4118 - val_y1_output_root_mean_squared_error: 2.7813 - val_y2_output_root_mean_squared_error: 2.8785
# Epoch 95/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.1313 - y1_output_loss: 0.9636 - y2_output_loss: 2.1580 - y1_output_root_mean_squared_error: 0.9848 - y2_output_root_mean_squared_error: 1.4702 - val_loss: 4.4470 - val_y1_output_loss: 1.2775 - val_y2_output_loss: 3.1973 - val_y1_output_root_mean_squared_error: 1.1029 - val_y2_output_root_mean_squared_error: 1.7974
# Epoch 96/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1837 - y1_output_loss: 0.8728 - y2_output_loss: 2.3157 - y1_output_root_mean_squared_error: 0.9388 - y2_output_root_mean_squared_error: 1.5174 - val_loss: 8.4994 - val_y1_output_loss: 0.7342 - val_y2_output_loss: 7.7117 - val_y1_output_root_mean_squared_error: 0.8448 - val_y2_output_root_mean_squared_error: 2.7903
# Epoch 97/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.0894 - y1_output_loss: 1.0682 - y2_output_loss: 3.0365 - y1_output_root_mean_squared_error: 1.0346 - y2_output_root_mean_squared_error: 1.7375 - val_loss: 4.6344 - val_y1_output_loss: 0.8733 - val_y2_output_loss: 3.6667 - val_y1_output_root_mean_squared_error: 0.9410 - val_y2_output_root_mean_squared_error: 1.9362
# Epoch 98/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9976 - y1_output_loss: 0.7095 - y2_output_loss: 2.2731 - y1_output_root_mean_squared_error: 0.8429 - y2_output_root_mean_squared_error: 1.5123 - val_loss: 2.5777 - val_y1_output_loss: 0.5349 - val_y2_output_loss: 2.0019 - val_y1_output_root_mean_squared_error: 0.7189 - val_y2_output_root_mean_squared_error: 1.4356
# Epoch 99/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.6047 - y1_output_loss: 0.8275 - y2_output_loss: 2.7523 - y1_output_root_mean_squared_error: 0.9112 - y2_output_root_mean_squared_error: 1.6656 - val_loss: 2.8746 - val_y1_output_loss: 0.6285 - val_y2_output_loss: 2.2043 - val_y1_output_root_mean_squared_error: 0.7800 - val_y2_output_root_mean_squared_error: 1.5054
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5101 - y1_output_loss: 0.6124 - y2_output_loss: 1.8917 - y1_output_root_mean_squared_error: 0.7823 - y2_output_root_mean_squared_error: 1.3777 - val_loss: 4.0942 - val_y1_output_loss: 1.5326 - val_y2_output_loss: 2.6207 - val_y1_output_root_mean_squared_error: 1.2296 - val_y2_output_root_mean_squared_error: 1.6070
# Epoch 101/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9456 - y1_output_loss: 0.6287 - y2_output_loss: 2.3101 - y1_output_root_mean_squared_error: 0.7950 - y2_output_root_mean_squared_error: 1.5210 - val_loss: 3.1532 - val_y1_output_loss: 0.6869 - val_y2_output_loss: 2.4305 - val_y1_output_root_mean_squared_error: 0.8201 - val_y2_output_root_mean_squared_error: 1.5750
# Epoch 102/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5645 - y1_output_loss: 0.6098 - y2_output_loss: 1.9391 - y1_output_root_mean_squared_error: 0.7842 - y2_output_root_mean_squared_error: 1.3963 - val_loss: 2.6422 - val_y1_output_loss: 0.6095 - val_y2_output_loss: 1.9531 - val_y1_output_root_mean_squared_error: 0.7880 - val_y2_output_root_mean_squared_error: 1.4217
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8594 - y1_output_loss: 0.6541 - y2_output_loss: 2.1861 - y1_output_root_mean_squared_error: 0.8106 - y2_output_root_mean_squared_error: 1.4841 - val_loss: 2.3230 - val_y1_output_loss: 0.3983 - val_y2_output_loss: 1.8633 - val_y1_output_root_mean_squared_error: 0.6259 - val_y2_output_root_mean_squared_error: 1.3897
# Epoch 104/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6445 - y1_output_loss: 0.6116 - y2_output_loss: 2.0386 - y1_output_root_mean_squared_error: 0.7803 - y2_output_root_mean_squared_error: 1.4268 - val_loss: 2.5941 - val_y1_output_loss: 0.6956 - val_y2_output_loss: 1.8600 - val_y1_output_root_mean_squared_error: 0.8240 - val_y2_output_root_mean_squared_error: 1.3838
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5699 - y1_output_loss: 0.6012 - y2_output_loss: 1.9474 - y1_output_root_mean_squared_error: 0.7776 - y2_output_root_mean_squared_error: 1.4019 - val_loss: 2.4936 - val_y1_output_loss: 0.5556 - val_y2_output_loss: 1.8849 - val_y1_output_root_mean_squared_error: 0.7397 - val_y2_output_root_mean_squared_error: 1.3951
# Epoch 106/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4217 - y1_output_loss: 0.7582 - y2_output_loss: 2.6702 - y1_output_root_mean_squared_error: 0.8713 - y2_output_root_mean_squared_error: 1.6317 - val_loss: 24.4989 - val_y1_output_loss: 4.7485 - val_y2_output_loss: 20.0801 - val_y1_output_root_mean_squared_error: 2.1212 - val_y2_output_root_mean_squared_error: 4.4721
# Epoch 107/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.6611 - y1_output_loss: 1.4947 - y2_output_loss: 4.1338 - y1_output_root_mean_squared_error: 1.2267 - y2_output_root_mean_squared_error: 2.0387 - val_loss: 2.9840 - val_y1_output_loss: 0.6057 - val_y2_output_loss: 2.3070 - val_y1_output_root_mean_squared_error: 0.7816 - val_y2_output_root_mean_squared_error: 1.5405
# Epoch 108/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4827 - y1_output_loss: 0.5719 - y2_output_loss: 1.9039 - y1_output_root_mean_squared_error: 0.7530 - y2_output_root_mean_squared_error: 1.3841 - val_loss: 2.8862 - val_y1_output_loss: 0.8798 - val_y2_output_loss: 1.9819 - val_y1_output_root_mean_squared_error: 0.9282 - val_y2_output_root_mean_squared_error: 1.4229
# Epoch 109/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8126 - y1_output_loss: 0.6570 - y2_output_loss: 2.1567 - y1_output_root_mean_squared_error: 0.8037 - y2_output_root_mean_squared_error: 1.4720 - val_loss: 2.8104 - val_y1_output_loss: 0.9713 - val_y2_output_loss: 1.8667 - val_y1_output_root_mean_squared_error: 0.9395 - val_y2_output_root_mean_squared_error: 1.3885
# Epoch 110/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.9090 - y1_output_loss: 0.6658 - y2_output_loss: 2.2305 - y1_output_root_mean_squared_error: 0.8146 - y2_output_root_mean_squared_error: 1.4985 - val_loss: 3.7149 - val_y1_output_loss: 0.8365 - val_y2_output_loss: 2.9196 - val_y1_output_root_mean_squared_error: 0.8741 - val_y2_output_root_mean_squared_error: 1.7178
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4697 - y1_output_loss: 0.6319 - y2_output_loss: 1.8196 - y1_output_root_mean_squared_error: 0.7964 - y2_output_root_mean_squared_error: 1.3548 - val_loss: 2.3869 - val_y1_output_loss: 0.5834 - val_y2_output_loss: 1.7598 - val_y1_output_root_mean_squared_error: 0.7642 - val_y2_output_root_mean_squared_error: 1.3427
# Epoch 112/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6897 - y1_output_loss: 0.6452 - y2_output_loss: 2.0457 - y1_output_root_mean_squared_error: 0.7980 - y2_output_root_mean_squared_error: 1.4328 - val_loss: 6.3943 - val_y1_output_loss: 1.7875 - val_y2_output_loss: 4.6768 - val_y1_output_root_mean_squared_error: 1.3317 - val_y2_output_root_mean_squared_error: 2.1496
# Epoch 113/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2590 - y1_output_loss: 0.5461 - y2_output_loss: 1.7295 - y1_output_root_mean_squared_error: 0.7380 - y2_output_root_mean_squared_error: 1.3093 - val_loss: 6.2042 - val_y1_output_loss: 1.7274 - val_y2_output_loss: 4.5136 - val_y1_output_root_mean_squared_error: 1.3087 - val_y2_output_root_mean_squared_error: 2.1193
# Epoch 114/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1679 - y1_output_loss: 0.7221 - y2_output_loss: 2.4699 - y1_output_root_mean_squared_error: 0.8512 - y2_output_root_mean_squared_error: 1.5631 - val_loss: 3.2748 - val_y1_output_loss: 0.7900 - val_y2_output_loss: 2.4711 - val_y1_output_root_mean_squared_error: 0.8716 - val_y2_output_root_mean_squared_error: 1.5859
# Epoch 115/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.9063 - y1_output_loss: 1.2147 - y2_output_loss: 3.7149 - y1_output_root_mean_squared_error: 1.1056 - y2_output_root_mean_squared_error: 1.9193 - val_loss: 7.4921 - val_y1_output_loss: 1.1554 - val_y2_output_loss: 6.2973 - val_y1_output_root_mean_squared_error: 1.0814 - val_y2_output_root_mean_squared_error: 2.5145
# Epoch 116/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.6039 - y1_output_loss: 0.7522 - y2_output_loss: 2.8192 - y1_output_root_mean_squared_error: 0.8708 - y2_output_root_mean_squared_error: 1.6869 - val_loss: 2.0896 - val_y1_output_loss: 0.4869 - val_y2_output_loss: 1.5701 - val_y1_output_root_mean_squared_error: 0.6888 - val_y2_output_root_mean_squared_error: 1.2709
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.3038 - y1_output_loss: 0.5142 - y2_output_loss: 1.7952 - y1_output_root_mean_squared_error: 0.7179 - y2_output_root_mean_squared_error: 1.3373 - val_loss: 4.9227 - val_y1_output_loss: 0.4975 - val_y2_output_loss: 4.3850 - val_y1_output_root_mean_squared_error: 0.7076 - val_y2_output_root_mean_squared_error: 2.1029
# Epoch 118/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.0504 - y1_output_loss: 0.5223 - y2_output_loss: 1.5127 - y1_output_root_mean_squared_error: 0.7248 - y2_output_root_mean_squared_error: 1.2350 - val_loss: 2.0520 - val_y1_output_loss: 0.4057 - val_y2_output_loss: 1.5855 - val_y1_output_root_mean_squared_error: 0.6391 - val_y2_output_root_mean_squared_error: 1.2820
# Epoch 119/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8227 - y1_output_loss: 0.7364 - y2_output_loss: 2.0684 - y1_output_root_mean_squared_error: 0.8598 - y2_output_root_mean_squared_error: 1.4434 - val_loss: 3.4090 - val_y1_output_loss: 0.7543 - val_y2_output_loss: 2.7196 - val_y1_output_root_mean_squared_error: 0.8238 - val_y2_output_root_mean_squared_error: 1.6524
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9589 - y1_output_loss: 0.6726 - y2_output_loss: 2.2844 - y1_output_root_mean_squared_error: 0.8228 - y2_output_root_mean_squared_error: 1.5106 - val_loss: 5.0534 - val_y1_output_loss: 1.0895 - val_y2_output_loss: 3.9726 - val_y1_output_root_mean_squared_error: 1.0355 - val_y2_output_root_mean_squared_error: 1.9953
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3991 - y1_output_loss: 0.1175 - y2_output_loss: 0.2791 - y1_output_root_mean_squared_error: 0.3427 - y2_output_root_mean_squared_error: 0.5307 - val_loss: 1.0588 - val_y1_output_loss: 0.2366 - val_y2_output_loss: 0.7924 - val_y1_output_root_mean_squared_error: 0.4951 - val_y2_output_root_mean_squared_error: 0.9020
# Epoch 462/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6360 - y1_output_loss: 0.1767 - y2_output_loss: 0.4595 - y1_output_root_mean_squared_error: 0.4215 - y2_output_root_mean_squared_error: 0.6770 - val_loss: 1.1820 - val_y1_output_loss: 0.2009 - val_y2_output_loss: 0.9472 - val_y1_output_root_mean_squared_error: 0.4495 - val_y2_output_root_mean_squared_error: 0.9899
# Epoch 463/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4282 - y1_output_loss: 0.1380 - y2_output_loss: 0.2883 - y1_output_root_mean_squared_error: 0.3730 - y2_output_root_mean_squared_error: 0.5376 - val_loss: 1.0120 - val_y1_output_loss: 0.2011 - val_y2_output_loss: 0.7935 - val_y1_output_root_mean_squared_error: 0.4430 - val_y2_output_root_mean_squared_error: 0.9032
# Epoch 464/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5193 - y1_output_loss: 0.1210 - y2_output_loss: 0.4014 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.6308 - val_loss: 1.0938 - val_y1_output_loss: 0.2518 - val_y2_output_loss: 0.8161 - val_y1_output_root_mean_squared_error: 0.4970 - val_y2_output_root_mean_squared_error: 0.9202
# Epoch 465/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4252 - y1_output_loss: 0.1220 - y2_output_loss: 0.3005 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5501 - val_loss: 0.9681 - val_y1_output_loss: 0.2144 - val_y2_output_loss: 0.7303 - val_y1_output_root_mean_squared_error: 0.4641 - val_y2_output_root_mean_squared_error: 0.8676
# Epoch 466/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5388 - y1_output_loss: 0.1349 - y2_output_loss: 0.4002 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.6350 - val_loss: 0.8742 - val_y1_output_loss: 0.1896 - val_y2_output_loss: 0.6662 - val_y1_output_root_mean_squared_error: 0.4378 - val_y2_output_root_mean_squared_error: 0.8262
# Epoch 467/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.8933 - y1_output_loss: 0.2451 - y2_output_loss: 0.6414 - y1_output_root_mean_squared_error: 0.4966 - y2_output_root_mean_squared_error: 0.8042 - val_loss: 1.0109 - val_y1_output_loss: 0.2092 - val_y2_output_loss: 0.7743 - val_y1_output_root_mean_squared_error: 0.4597 - val_y2_output_root_mean_squared_error: 0.8942
# Epoch 468/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6362 - y1_output_loss: 0.1743 - y2_output_loss: 0.4628 - y1_output_root_mean_squared_error: 0.4160 - y2_output_root_mean_squared_error: 0.6805 - val_loss: 1.6183 - val_y1_output_loss: 0.4811 - val_y2_output_loss: 1.1201 - val_y1_output_root_mean_squared_error: 0.6994 - val_y2_output_root_mean_squared_error: 1.0626
# Epoch 469/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4574 - y1_output_loss: 0.1397 - y2_output_loss: 0.3156 - y1_output_root_mean_squared_error: 0.3751 - y2_output_root_mean_squared_error: 0.5628 - val_loss: 0.9180 - val_y1_output_loss: 0.2325 - val_y2_output_loss: 0.6798 - val_y1_output_root_mean_squared_error: 0.4746 - val_y2_output_root_mean_squared_error: 0.8324
# Epoch 470/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6651 - y1_output_loss: 0.1600 - y2_output_loss: 0.5003 - y1_output_root_mean_squared_error: 0.4007 - y2_output_root_mean_squared_error: 0.7103 - val_loss: 0.9362 - val_y1_output_loss: 0.1993 - val_y2_output_loss: 0.7222 - val_y1_output_root_mean_squared_error: 0.4407 - val_y2_output_root_mean_squared_error: 0.8614
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.8491 - y1_output_loss: 0.1718 - y2_output_loss: 0.6728 - y1_output_root_mean_squared_error: 0.4161 - y2_output_root_mean_squared_error: 0.8222 - val_loss: 1.1944 - val_y1_output_loss: 0.1696 - val_y2_output_loss: 1.0038 - val_y1_output_root_mean_squared_error: 0.4140 - val_y2_output_root_mean_squared_error: 1.0115
# Epoch 472/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4446 - y1_output_loss: 0.1284 - y2_output_loss: 0.3271 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5628 - val_loss: 2.8348 - val_y1_output_loss: 0.3473 - val_y2_output_loss: 2.4151 - val_y1_output_root_mean_squared_error: 0.5901 - val_y2_output_root_mean_squared_error: 1.5769
# Epoch 473/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4672 - y1_output_loss: 0.1489 - y2_output_loss: 0.3171 - y1_output_root_mean_squared_error: 0.3875 - y2_output_root_mean_squared_error: 0.5631 - val_loss: 0.9729 - val_y1_output_loss: 0.1753 - val_y2_output_loss: 0.7807 - val_y1_output_root_mean_squared_error: 0.4160 - val_y2_output_root_mean_squared_error: 0.8943
# Epoch 474/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4255 - y1_output_loss: 0.1233 - y2_output_loss: 0.3048 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.5493 - val_loss: 1.1743 - val_y1_output_loss: 0.3173 - val_y2_output_loss: 0.8313 - val_y1_output_root_mean_squared_error: 0.5715 - val_y2_output_root_mean_squared_error: 0.9207
# Epoch 475/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4725 - y1_output_loss: 0.1331 - y2_output_loss: 0.3396 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.5826 - val_loss: 1.3907 - val_y1_output_loss: 0.3131 - val_y2_output_loss: 1.0510 - val_y1_output_root_mean_squared_error: 0.5682 - val_y2_output_root_mean_squared_error: 1.0334
# Epoch 476/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4812 - y1_output_loss: 0.1353 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3690 - y2_output_root_mean_squared_error: 0.5874 - val_loss: 0.9727 - val_y1_output_loss: 0.1781 - val_y2_output_loss: 0.7747 - val_y1_output_root_mean_squared_error: 0.4179 - val_y2_output_root_mean_squared_error: 0.8933
# Epoch 477/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4144 - y1_output_loss: 0.1327 - y2_output_loss: 0.2814 - y1_output_root_mean_squared_error: 0.3614 - y2_output_root_mean_squared_error: 0.5327 - val_loss: 0.9688 - val_y1_output_loss: 0.2349 - val_y2_output_loss: 0.7320 - val_y1_output_root_mean_squared_error: 0.4731 - val_y2_output_root_mean_squared_error: 0.8632
# Epoch 478/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4817 - y1_output_loss: 0.1341 - y2_output_loss: 0.3449 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5894 - val_loss: 0.9036 - val_y1_output_loss: 0.1833 - val_y2_output_loss: 0.7023 - val_y1_output_root_mean_squared_error: 0.4244 - val_y2_output_root_mean_squared_error: 0.8506
# Epoch 479/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4005 - y1_output_loss: 0.1192 - y2_output_loss: 0.2823 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5297 - val_loss: 1.7479 - val_y1_output_loss: 0.3557 - val_y2_output_loss: 1.3899 - val_y1_output_root_mean_squared_error: 0.6034 - val_y2_output_root_mean_squared_error: 1.1764
# Epoch 480/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5401 - y1_output_loss: 0.1345 - y2_output_loss: 0.4006 - y1_output_root_mean_squared_error: 0.3685 - y2_output_root_mean_squared_error: 0.6359 - val_loss: 0.8657 - val_y1_output_loss: 0.2037 - val_y2_output_loss: 0.6536 - val_y1_output_root_mean_squared_error: 0.4442 - val_y2_output_root_mean_squared_error: 0.8175
# Epoch 481/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4581 - y1_output_loss: 0.1198 - y2_output_loss: 0.3355 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.5812 - val_loss: 0.8878 - val_y1_output_loss: 0.1790 - val_y2_output_loss: 0.6872 - val_y1_output_root_mean_squared_error: 0.4276 - val_y2_output_root_mean_squared_error: 0.8396
# Epoch 482/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5265 - y1_output_loss: 0.1436 - y2_output_loss: 0.3854 - y1_output_root_mean_squared_error: 0.3804 - y2_output_root_mean_squared_error: 0.6179 - val_loss: 1.1624 - val_y1_output_loss: 0.2095 - val_y2_output_loss: 0.9323 - val_y1_output_root_mean_squared_error: 0.4628 - val_y2_output_root_mean_squared_error: 0.9738
# Epoch 483/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4320 - y1_output_loss: 0.1545 - y2_output_loss: 0.2752 - y1_output_root_mean_squared_error: 0.3936 - y2_output_root_mean_squared_error: 0.5264 - val_loss: 0.9603 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.7677 - val_y1_output_root_mean_squared_error: 0.4122 - val_y2_output_root_mean_squared_error: 0.8890
# Epoch 484/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3954 - y1_output_loss: 0.1047 - y2_output_loss: 0.2903 - y1_output_root_mean_squared_error: 0.3233 - y2_output_root_mean_squared_error: 0.5393 - val_loss: 1.4855 - val_y1_output_loss: 0.4515 - val_y2_output_loss: 1.0549 - val_y1_output_root_mean_squared_error: 0.6520 - val_y2_output_root_mean_squared_error: 1.0298
# Epoch 485/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3893 - y1_output_loss: 0.1243 - y2_output_loss: 0.2641 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.5139 - val_loss: 1.0877 - val_y1_output_loss: 0.2240 - val_y2_output_loss: 0.8660 - val_y1_output_root_mean_squared_error: 0.4622 - val_y2_output_root_mean_squared_error: 0.9349
# Epoch 486/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3947 - y1_output_loss: 0.1036 - y2_output_loss: 0.2918 - y1_output_root_mean_squared_error: 0.3221 - y2_output_root_mean_squared_error: 0.5394 - val_loss: 0.8851 - val_y1_output_loss: 0.2197 - val_y2_output_loss: 0.6583 - val_y1_output_root_mean_squared_error: 0.4622 - val_y2_output_root_mean_squared_error: 0.8194
# Epoch 487/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4097 - y1_output_loss: 0.1199 - y2_output_loss: 0.2871 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.5381 - val_loss: 0.8321 - val_y1_output_loss: 0.1862 - val_y2_output_loss: 0.6266 - val_y1_output_root_mean_squared_error: 0.4285 - val_y2_output_root_mean_squared_error: 0.8053
# Epoch 488/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3557 - y1_output_loss: 0.1167 - y2_output_loss: 0.2381 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4889 - val_loss: 1.0790 - val_y1_output_loss: 0.2053 - val_y2_output_loss: 0.8447 - val_y1_output_root_mean_squared_error: 0.4544 - val_y2_output_root_mean_squared_error: 0.9341
# Epoch 489/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3809 - y1_output_loss: 0.1148 - y2_output_loss: 0.2635 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.5150 - val_loss: 0.9103 - val_y1_output_loss: 0.1764 - val_y2_output_loss: 0.7150 - val_y1_output_root_mean_squared_error: 0.4258 - val_y2_output_root_mean_squared_error: 0.8538
# Epoch 490/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5440 - y1_output_loss: 0.1262 - y2_output_loss: 0.4253 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.6495 - val_loss: 2.9647 - val_y1_output_loss: 0.8272 - val_y2_output_loss: 2.1971 - val_y1_output_root_mean_squared_error: 0.8807 - val_y2_output_root_mean_squared_error: 1.4796
# Epoch 491/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5403 - y1_output_loss: 0.1618 - y2_output_loss: 0.3858 - y1_output_root_mean_squared_error: 0.3956 - y2_output_root_mean_squared_error: 0.6195 - val_loss: 0.9954 - val_y1_output_loss: 0.3069 - val_y2_output_loss: 0.6598 - val_y1_output_root_mean_squared_error: 0.5633 - val_y2_output_root_mean_squared_error: 0.8235
# Epoch 492/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4628 - y1_output_loss: 0.1693 - y2_output_loss: 0.2910 - y1_output_root_mean_squared_error: 0.4126 - y2_output_root_mean_squared_error: 0.5409 - val_loss: 0.9404 - val_y1_output_loss: 0.1807 - val_y2_output_loss: 0.7385 - val_y1_output_root_mean_squared_error: 0.4247 - val_y2_output_root_mean_squared_error: 0.8718
# Epoch 493/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3710 - y1_output_loss: 0.1098 - y2_output_loss: 0.2585 - y1_output_root_mean_squared_error: 0.3328 - y2_output_root_mean_squared_error: 0.5102 - val_loss: 0.9666 - val_y1_output_loss: 0.1808 - val_y2_output_loss: 0.7715 - val_y1_output_root_mean_squared_error: 0.4209 - val_y2_output_root_mean_squared_error: 0.8885
# Epoch 494/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4275 - y1_output_loss: 0.1217 - y2_output_loss: 0.3063 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.5543 - val_loss: 1.0298 - val_y1_output_loss: 0.3301 - val_y2_output_loss: 0.7155 - val_y1_output_root_mean_squared_error: 0.5570 - val_y2_output_root_mean_squared_error: 0.8483
# Epoch 495/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3748 - y1_output_loss: 0.1244 - y2_output_loss: 0.2475 - y1_output_root_mean_squared_error: 0.3539 - y2_output_root_mean_squared_error: 0.4996 - val_loss: 1.0441 - val_y1_output_loss: 0.2033 - val_y2_output_loss: 0.8309 - val_y1_output_root_mean_squared_error: 0.4514 - val_y2_output_root_mean_squared_error: 0.9167
# Epoch 496/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3735 - y1_output_loss: 0.1024 - y2_output_loss: 0.2701 - y1_output_root_mean_squared_error: 0.3204 - y2_output_root_mean_squared_error: 0.5205 - val_loss: 1.3014 - val_y1_output_loss: 0.2635 - val_y2_output_loss: 1.0099 - val_y1_output_root_mean_squared_error: 0.5223 - val_y2_output_root_mean_squared_error: 1.0142
# Epoch 497/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4902 - y1_output_loss: 0.1348 - y2_output_loss: 0.3687 - y1_output_root_mean_squared_error: 0.3630 - y2_output_root_mean_squared_error: 0.5986 - val_loss: 3.1972 - val_y1_output_loss: 1.1121 - val_y2_output_loss: 2.0786 - val_y1_output_root_mean_squared_error: 1.0517 - val_y2_output_root_mean_squared_error: 1.4461
# Epoch 498/500
# 614/614 [==============================] - 0s 131us/sample - loss: 1.0504 - y1_output_loss: 0.2481 - y2_output_loss: 0.8042 - y1_output_root_mean_squared_error: 0.4996 - y2_output_root_mean_squared_error: 0.8948 - val_loss: 3.4153 - val_y1_output_loss: 0.7172 - val_y2_output_loss: 2.6976 - val_y1_output_root_mean_squared_error: 0.8343 - val_y2_output_root_mean_squared_error: 1.6490
# Epoch 499/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5291 - y1_output_loss: 0.1526 - y2_output_loss: 0.3732 - y1_output_root_mean_squared_error: 0.3921 - y2_output_root_mean_squared_error: 0.6126 - val_loss: 0.8943 - val_y1_output_loss: 0.1950 - val_y2_output_loss: 0.6749 - val_y1_output_root_mean_squared_error: 0.4419 - val_y2_output_root_mean_squared_error: 0.8360
# Epoch 500/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5091 - y1_output_loss: 0.1226 - y2_output_loss: 0.3933 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.6215 - val_loss: 2.4903 - val_y1_output_loss: 0.3570 - val_y2_output_loss: 2.0917 - val_y1_output_root_mean_squared_error: 0.6059 - val_y2_output_root_mean_squared_error: 1.4571

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 33us/sample - loss: 2.4903 - y1_output_loss: 0.3595 - y2_output_loss: 2.1004 - y1_output_root_mean_squared_error: 0.6059 - y2_output_root_mean_squared_error: 1.4571
# Loss = 2.4903132420081597, Y1_loss = 0.35950082540512085, Y1_mse = 0.6058729290962219, Y2_loss = 2.1003916263580322, Y2_mse = 1.4571311473846436

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
